# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

df=pd.read_csv("loan_approval_data.csv")
df.head(70)
# Out:
#     Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0            1.0           17795.0              1387.0          Salaried
# 1            2.0            2860.0              2679.0          Salaried
# 2            3.0            7390.0              2106.0          Salaried
# 3            4.0           13964.0              8173.0          Salaried
# 4            5.0           13284.0              4223.0     Self-employed
# ..           ...               ...                 ...               ...
# 65          66.0           11268.0              6212.0          Salaried
# 66          67.0           14185.0              7479.0          Salaried
# 67          68.0            8331.0              5408.0          Salaried
# 68          69.0           10571.0              9977.0          Salaried
# 69          70.0            9208.0              7715.0        Unemployed
#
#      Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# ...

# %% [markdown]
# # Handling Missing Values

# %%
cat_columns=df.select_dtypes(include=["object"]).columns
num_columns=df.select_dtypes(include=["number"]).columns

# %%
num_columns
# Out:
# Index(['Applicant_ID', 'Applicant_Income', 'Coapplicant_Income', 'Age',
#        'Dependents', 'Credit_Score', 'Existing_Loans', 'DTI_Ratio', 'Savings',
#        'Collateral_Value', 'Loan_Amount', 'Loan_Term'],
#       dtype='object')

# %%
cat_columns.size+num_columns.size
# Out:
# 20

# %%
cat_columns
# Out:
# Index(['Employment_Status', 'Marital_Status', 'Loan_Purpose', 'Property_Area',
#        'Education_Level', 'Gender', 'Employer_Category', 'Loan_Approved'],
#       dtype='object')

# %%
df[num_columns].head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income   Age  Dependents  \
# 0           1.0           17795.0              1387.0  51.0         0.0
# 1           2.0            2860.0              2679.0  46.0         3.0
# 2           3.0            7390.0              2106.0  25.0         2.0
# 3           4.0           13964.0              8173.0  40.0         2.0
# 4           5.0           13284.0              4223.0  31.0         2.0
#
#    Credit_Score  Existing_Loans  DTI_Ratio  Savings  Collateral_Value  \
# 0         637.0             4.0       0.53  19403.0           45638.0
# 1         621.0             2.0       0.30   2580.0           49272.0
# 2         674.0             4.0       0.20  13844.0            6908.0
# 3         579.0             3.0       0.31   9553.0           10844.0
# 4         721.0             1.0       0.29   9386.0           37629.0
#
#    Loan_Amount  Loan_Term
# 0      16619.0       84.0
# 1      38687.0       48.0
# 2      27943.0       72.0
# ...

# %%
from sklearn.impute import SimpleImputer

num_imp=SimpleImputer(strategy="mean")
df[num_columns]=num_imp.fit_transform(df[num_columns])
cat_imp=SimpleImputer(strategy="most_frequent")
df[cat_columns]=cat_imp.fit_transform(df[cat_columns])

# %%
df[num_columns]
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income   Age  Dependents  \
# 0             1.0      17795.000000              1387.0  51.0         0.0
# 1             2.0       2860.000000              2679.0  46.0         3.0
# 2             3.0       7390.000000              2106.0  25.0         2.0
# 3             4.0      13964.000000              8173.0  40.0         2.0
# 4             5.0      13284.000000              4223.0  31.0         2.0
# ..            ...               ...                 ...   ...         ...
# 995         996.0      10852.571579              9092.0  58.0         0.0
# 996         997.0       3279.000000              6356.0  58.0         1.0
# 997         998.0      15192.000000              8433.0  48.0         1.0
# 998         999.0       9083.000000              7380.0  50.0         1.0
# 999        1000.0      13093.000000              2385.0  23.0         1.0
#
#      Credit_Score  Existing_Loans  DTI_Ratio       Savings  Collateral_Value  \
# ...

# %%
df[cat_columns]
# Out:
#     Employment_Status Marital_Status Loan_Purpose Property_Area  \
# 0            Salaried        Married     Personal         Urban
# 1            Salaried        Married          Car     Semiurban
# 2            Salaried         Single     Business         Urban
# 3            Salaried        Married     Business         Rural
# 4       Self-employed         Single          Car         Urban
# ..                ...            ...          ...           ...
# 995          Salaried        Married     Personal         Urban
# 996     Self-employed        Married     Business         Urban
# 997          Contract         Single         Home         Rural
# 998        Unemployed         Single     Personal         Urban
# 999          Salaried        Married     Personal     Semiurban
#
#     Education_Level  Gender Employer_Category Loan_Approved
# 0      Not Graduate  Female           Private            No
# 1          Graduate    Male           Private            No
# ...

# %% [markdown]
# # EDA -Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        1000 non-null   float64
#  1   Applicant_Income    1000 non-null   float64
#  2   Coapplicant_Income  1000 non-null   float64
#  3   Employment_Status   1000 non-null   object
#  4   Age                 1000 non-null   float64
#  5   Marital_Status      1000 non-null   object
#  6   Dependents          1000 non-null   float64
#  7   Credit_Score        1000 non-null   float64
#  8   Existing_Loans      1000 non-null   float64
#  9   DTI_Ratio           1000 non-null   float64
#  10  Savings             1000 non-null   float64
#  11  Collateral_Value    1000 non-null   float64
#  12  Loan_Amount         1000 non-null   float64
#  13  Loan_Term           1000 non-null   float64
#  14  Loan_Purpose        1000 non-null   object
# ...

# %%
op_count=df["Loan_Approved"].value_counts()

# %%
op_count
# Out:
# Loan_Approved
# No     702
# Yes    298
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(op_count,labels=["No","Yes"],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1933e684ec0>,
# ...
#  [Text(-0.6521425375337495, 0.8858386482531919, 'No'),
#   Text(0.6521428261765839, -0.8858384357581341, 'Yes')],
#  [Text(-0.3557141113820451, 0.48318471722901374, '70.2%'),
#   Text(0.3557142688235912, -0.4831846013226186, '29.8%')])

# %%
#analysing Categories
gender_count=df["Gender"].value_counts()
plot=sns.barplot(gender_count)
plot.bar_label(plot.containers[0])
# Out:
# [Text(0, 0, '621'), Text(0, 0, '379')]

# %%
edu_cnt=df["Education_Level"].value_counts()
plot=sns.barplot(edu_cnt)
plot.bar_label(plot.containers[0])
# Out:
# [Text(0, 0, '722'), Text(0, 0, '278')]

# %%
#analysing income
plot=sns.histplot(data=df,
                    x="Applicant_Income",
                  bins=20)

# %%
sns.histplot(data=df,
             x="Coapplicant_Income",
             bins=20)
# Out:
# <Axes: xlabel='Coapplicant_Income', ylabel='Count'>

# %%
#outlier anaylysis using BOX PLOT
fig,axes=plt.subplots(2,2)
sns.boxplot(ax=axes[0,0],data=df,
            x="Loan_Approved",
            y="Applicant_Income"
           )
sns.boxplot(ax=axes[0,1],data=df,
            x="Loan_Approved",
            y="Credit_Score"
           )
sns.boxplot(ax=axes[1,0],
            data=df,
            x="Loan_Approved",
            y="DTI_Ratio"
           )
sns.boxplot(ax=axes[1,1],
            data=df,
            x="Loan_Approved",
            y="Savings"
           )
# Out:
# <Axes: xlabel='Loan_Approved', ylabel='Savings'>

# %%
#Anaylysing Credit Score
sns.histplot(data=df,
             x="Credit_Score",
             hue="Loan_Approved",
             multiple="dodge"
            )
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
#Anaylysing Applicant Income
sns.histplot(data=df,
             x="Applicant_Income",
             hue="Loan_Approved",
             multiple="dodge"
            )
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
#CREDIT SCORE IS MORE IMP FEATURE TO DECIDE LOAN APPROVAL
#SUCH DECISIONS ARE MADE WITH EDA using CHARTS like this and observing some pattern

# %%
#REMOVE APPLICANT_ID as it doesnt have any work to decide loan_approval
df=df.drop("Applicant_ID",axis=1)

# %%
df
# Out:
#      Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0        17795.000000              1387.0          Salaried  51.0
# 1         2860.000000              2679.0          Salaried  46.0
# 2         7390.000000              2106.0          Salaried  25.0
# 3        13964.000000              8173.0          Salaried  40.0
# 4        13284.000000              4223.0     Self-employed  31.0
# ..                ...                 ...               ...   ...
# 995      10852.571579              9092.0          Salaried  58.0
# 996       3279.000000              6356.0     Self-employed  58.0
# 997      15192.000000              8433.0          Contract  48.0
# 998       9083.000000              7380.0        Unemployed  50.0
# 999      13093.000000              2385.0          Salaried  23.0
#
#     Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0          Married         0.0         637.0             4.0       0.53
# ...
