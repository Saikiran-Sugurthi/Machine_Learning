# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df=pd.read_csv("thyroid_dataset.csv")
x=df.drop("Outlier_label",axis=1)
y=df["Outlier_label"]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
from sklearn.neighbors import LocalOutlierFactor
lof=LocalOutlierFactor()
labels=lof.fit_predict(x_scaled)

# %%
from sklearn.decomposition import PCA 
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x_scaled)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=labels)

# %%
import numpy as np
print("outliers : ",np.sum(labels==-1))
print("normal : ",np.sum(labels==1))
# Out:
# outliers :  883
# normal :  6033

# %%
## here outliers number is very high ,as LOF recognised LOCAL OUTLIERS ALSO,which are ignored
## by other alogorithms 
## if local outliers are ignored ,the count would be around 250

# %% [markdown]
# ## BY SPECIFYING CONTAMINATION

# %%
lof=LocalOutlierFactor(contamination=0.036)
labels=lof.fit_predict(x_scaled)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=labels)

# %%
print("Outilers :",np.sum(labels==-1))
print("Normal : ",np.sum(labels==1))
# Out:
# Outilers : 249
# Normal :  6667
