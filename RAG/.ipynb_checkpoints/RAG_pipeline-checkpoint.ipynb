# %% [markdown]
# ## Ingestion Pipeline

# %%
import os
from langchain_community.document_loaders.pdf import PyPDFLoader
# Out:
# C:\Users\Sai Kiran Sugurthi\AppData\Local\Temp\ipykernel_15056\2748893930.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
def load_all_pdfs():
    folder_path="data/pdfs"
    num_docs=0
    all_docs=[]

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            #create complete file path
            pdf_path=os.path.join(folder_path,filename)

            loader=PyPDFLoader(pdf_path)
            doc=loader.load()

            all_docs.extend(doc)
            num_docs+=1
    print("total pdfs:",num_docs)
    print("total pages:",len(all_docs))
    return all_docs

# %%
all_pdf_docs=load_all_pdfs()
# Out:
# total pdfs: 1
# total pages: 21

# %%
#CREATING CHUNKS FROM DOCUMENTS

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
def split_docs(documents,chunk_size=500,chunk_overlap=50):
    text_splitter=RecursiveCharacterTextSplitter(chunk_size=chunk_size,chunk_overlap=chunk_overlap)
    chunks=text_splitter.split_documents(documents)
    return chunks;

# %%
chunks=split_docs(all_pdf_docs)
# chunks

# %%
len(chunks)
# Out:
# 244

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (5.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (1.20.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: certifi in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: colorama in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sai kiran sugurthi\appdata\local\programs\python\python314\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## CREATING EMBEDDINGS

# %%
from sentence_transformers import SentenceTransformer

class EmbeddingManager:
    def __init__(self,model_name="all-MiniLM-L6-v2"):
        self.model_name=model_name
        print("loading model ...",self.model_name)
        self.model=SentenceTransformer(self.model_name)
        print("embedding Dimensions : ",self.model.get_sentence_embedding_dimension())

    def generate_embeddings(self,text):
        embeddings=self.model.encode(text,show_progress_bar=True)
        print("Embeddings shape :",embeddings.shape)
        return embeddings

# %%
embedding_manager=EmbeddingManager()
# Out:
# loading model ... all-MiniLM-L6-v2
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 8625.09it/s]
# embedding Dimensions :  384
# C:\Users\Sai Kiran Sugurthi\AppData\Local\Temp\ipykernel_15056\3851264641.py:8: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print("embedding Dimensions : ",self.model.get_sentence_embedding_dimension())

# %% [markdown]
# ## Vector Store

# %%
import chromadb
import uuid

# %%
class VectorStoreManager:
    def __init__(self,persistent_directory="data/vector_store",collection_name="pdf_documents"):
        self.collection_name=collection_name;
        self.persistent_directory=persistent_directory
        self.collection=None
        self.client=None

        self._initialise_store()

    def _initialise_store(self):
        os.makedirs(self.persistent_directory,exist_ok=True)

        # Create a Client
        self.client=chromadb.PersistentClient(path=self.persistent_directory)

        #Create the collection
        self.collection=self.client.get_or_create_collection(
            name=self.collection_name,
            metadata={"description":"vector store collection for pdf embeddings in RAG"}
        )

        print("initialised the vector store with collection :",self.collection_name)

    def add_documents(self,documents,embeddings):
        if len(documents)!=len(embeddings):
            raise ValueError("Docs length doesn't match embeddings length")

        ids=[]
        all_metadata=[]
        documents_content=[]
        embeddings_list=[]
        
        for i,(doc,embedding) in enumerate(zip(documents,embeddings)):
            doc_id=f"doc_{uuid.uuid4()}"
            ids.append(doc_id)

            metadata=dict(doc.metadata)
            metadata["doc_index"]=i
            metadata["content_length"]=len(doc.page_content)
            all_metadata.append(metadata)

            documents_content.append(doc.page_content)
            embeddings_list.append(embedding)

        self.collection.add(
            ids=ids,
            metadatas=all_metadata,
            documents=documents_content,
            embeddings=embeddings_list)

        print("total documets added in the vector store :",len(documents_content))
        print("docs in collection :",self.collection.count())

# %%
vectorstoremanager=VectorStoreManager()
# Out:
# initialised the vector store with collection : pdf_documents

# %%
#doc=> chunk => embeddings => vector store

# %%
texts=[doc.page_content for doc in chunks]

embeddings=embedding_manager.generate_embeddings(texts)
vectorstoremanager.add_documents(chunks,embeddings)
# Out:
# Batches: 100%|██████████| 8/8 [00:12<00:00,  1.54s/it]
# Embeddings shape : (244, 384)
# total documets added in the vector store : 244
# docs in collection : 244

# %% [markdown]
# ## Retrieval Pipeline

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class RAGRetriever:
    def __init__(self,embedding_manager,vector_store):
        self.embedding_manager=embedding_manager
        self.vector_store=vector_store

    def retrieve(self,query,top_k=5,score_threshold=0.0):
        # query => embeddings
        query_embeddings=self.embedding_manager.generate_embeddings([query])[0]

        #similarity search
        results=self.vector_store.collection.query(
            query_embeddings=query_embeddings,
            n_results=top_k
        )

        #cosine similarity
        retrieved_docs=[]
        if results["documents"] and results["documents"][0]:
            ids=results["ids"][0]
            metadata=results["metadatas"][0]
            documents=results["documents"][0]
            distances=results["distances"][0]

            for i,(doc_id,metadata,document,distance) in enumerate(zip(ids,metadata,documents,distances)):
                similarity_score=1-distance

                if similarity_score>=score_threshold:
                    retrieved_docs.append({
                        "id":doc_id,
                        "document":document,
                        "metadata":metadata,
                        "distance":distance,
                        "similarity_score":similarity_score,
                        "rank":i+1
                    })     
        else:
            print("No documents found ")

        return retrieved_docs;

# %%
rag=RAGRetriever(embedding_manager,vectorstoremanager)
rag.retrieve("What is RAG")
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Embeddings shape : (1, 384)
# [{'id': 'doc_b304d35b-e267-492a-9d63-273f68691a83',
#   'document': 'and speculate on upcoming trends and innovations.\nOur contributions are as follows:\n• In this survey, we present a thorough and systematic\nreview of the state-of-the-art RAG methods, delineating\nits evolution through paradigms including naive RAG,\narXiv:2312.10997v5  [cs.CL]  27 Mar 2024',
#   'metadata': {'doc_index': 11,
#    'content_length': 288,
#    'page': 0,
#    'total_pages': 21,
#    'moddate': '2024-03-28T00:54:45+00:00',
#    'title': '',
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#    'page_label': '1',
#    'creationdate': '2024-03-28T00:54:45+00:00',
#    'keywords': '',
#    'subject': '',
#    'author': '',
#    'trapped': '/False',
#    'producer': 'pdfTeX-1.40.25',
#    'source': 'data/pdfs\\research2 .pdf',
#    'creator': 'LaTeX with hyperref'},
#   'distance': 0.4226757287979126,
#   'similarity_score': 0.5773242712020874,
#   'rank': 1},
#  {'id': 'doc_edd2d7e1-cb1e-4cdf-9d9f-271822043ddd',
#   'document': 'effective RAG framework.\n• We have summarized the current assessment methods of\nRAG, covering 26 tasks, nearly 50 datasets, outlining\nthe evaluation objectives and metrics, as well as the\ncurrent evaluation benchmarks and tools. Additionally,\nwe anticipate future directions for RAG, emphasizing\npotential enhancements to tackle current challenges.\nThe paper unfolds as follows: Section II introduces the\nmain concept and current paradigms of RAG. The following',
#   'metadata': {'doc_index': 14,
#    'keywords': '',
#    'total_pages': 21,
#    'author': '',
#    'creationdate': '2024-03-28T00:54:45+00:00',
#    'producer': 'pdfTeX-1.40.25',
#    'creator': 'LaTeX with hyperref',
#    'content_length': 461,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#    'source': 'data/pdfs\\research2 .pdf',
#    'moddate': '2024-03-28T00:54:45+00:00',
#    'title': '',
#    'subject': '',
#    'page_label': '2',
#    'trapped': '/False',
#    'page': 1},
#   'distance': 0.5319436192512512,
#   'similarity_score': 0.4680563807487488,
#   'rank': 2},
#  {'id': 'doc_6a63eeef-3f73-4bf2-8343-ed5fb9e6af7a',
#   'document': 'fine-tuning techniques.\nThe burgeoning field of RAG has experienced swift growth,\nyet it has not been accompanied by a systematic synthesis that\ncould clarify its broader trajectory. This survey endeavors to\nfill this gap by mapping out the RAG process and charting\nits evolution and anticipated future paths, with a focus on the\nintegration of RAG within LLMs. This paper considers both\ntechnical paradigms and research methods, summarizing three',
#   'metadata': {'author': '',
#    'trapped': '/False',
#    'source': 'data/pdfs\\research2 .pdf',
#    'total_pages': 21,
#    'doc_index': 8,
#    'moddate': '2024-03-28T00:54:45+00:00',
#    'subject': '',
#    'creationdate': '2024-03-28T00:54:45+00:00',
#    'content_length': 447,
#    'producer': 'pdfTeX-1.40.25',
#    'page': 0,
#    'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#    'title': '',
#    'creator': 'LaTeX with hyperref',
#    'page_label': '1',
#    'keywords': ''},
#   'distance': 0.621597945690155,
#   'similarity_score': 0.37840205430984497,
#   'rank': 3},
#  {'id': 'doc_3f813a16-6f48-4f72-885c-00809bc0be4b',
#   'document': 'a robust framework for the systematic evaluation of RAG\nmodels, as summarized in Table IV.\nVII. D ISCUSSION AND FUTURE PROSPECTS\nDespite the considerable progress in RAG technology, sev-\neral challenges persist that warrant in-depth research.This\nchapter will mainly introduce the current challenges and future\nresearch directions faced by RAG.\nA. RAG vs Long Context\nWith the deepening of related research, the context of LLMs\nis continuously expanding [170]–[172]. Presently, LLMs can',
#   'metadata': {'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#    'title': '',
#    'doc_index': 140,
#    'page': 13,
#    'source': 'data/pdfs\\research2 .pdf',
#    'total_pages': 21,
#    'trapped': '/False',
#    'content_length': 486,
#    'creationdate': '2024-03-28T00:54:45+00:00',
#    'subject': '',
#    'author': '',
#    'creator': 'LaTeX with hyperref',
#    'producer': 'pdfTeX-1.40.25',
#    'moddate': '2024-03-28T00:54:45+00:00',
#    'keywords': '',
#    'page_label': '14'},
#   'distance': 0.65409916639328,
#   'similarity_score': 0.34590083360671997,
#   'rank': 4},
#  {'id': 'doc_656e1d16-7206-4ac1-b0c9-6935858f34d4',
#   'document': 'main research paradigms from over 100 RAG studies, and\nanalyzing key technologies in the core stages of “Retrieval,”\n“Generation,” and “Augmentation.” On the other hand, current\nresearch tends to focus more on methods, lacking analysis and\nsummarization of how to evaluate RAG. This paper compre-\nhensively reviews the downstream tasks, datasets, benchmarks,\nand evaluation methods applicable to RAG. Overall, this\npaper sets out to meticulously compile and categorize the',
#   'metadata': {'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#    'title': '',
#    'source': 'data/pdfs\\research2 .pdf',
#    'trapped': '/False',
#    'creationdate': '2024-03-28T00:54:45+00:00',
#    'page_label': '1',
#    'author': '',
#    'page': 0,
#    'total_pages': 21,
#    'keywords': '',
#    'content_length': 472,
#    'producer': 'pdfTeX-1.40.25',
#    'moddate': '2024-03-28T00:54:45+00:00',
#    'doc_index': 9,
#    'creator': 'LaTeX with hyperref',
#    'subject': ''},
#   'distance': 0.6906401515007019,
#   'similarity_score': 0.3093598484992981,
#   'rank': 5}]

# %% [markdown]
# ## Integrating with LLM

# %%
API_KEY_GROQ="#"

# %%
# !pip install langchain-groq

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(
    groq_api_key=API_KEY_GROQ,
    model="qwen/qwen3-32b",
    temperature=0.1,
    max_tokens=1024
)

# %%
# generate our retriveal augmented output
def generate_output(query,retriever,llm,top_k=3):
    results=retriever.retrieve(query,top_k)

    context= "\n".join(doc["document"] for doc in results)  if results else ""

    if not context:
         print("we found no relevant context for the given query")

    prompt=f""" use given context to generate answer for the given query
            Context:{context},
            Query:{query} """
    response=llm.invoke([prompt.format(context=context,query=query)])
    
    return response.content

# %%
answer=generate_output("What is RAG",rag,llm)
print(answer)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 54.37it/s]
# Embeddings shape : (1, 384)
# <think>
# Okay, the user is asking, "What is RAG?" I need to use the provided context to answer this. Let me start by reading through the context carefully.
#
# The context mentions that the paper is a survey on RAG methods, covering their evolution through paradigms like naive RAG and effective RAG frameworks. It also talks about evaluation methods, tasks, datasets, and future directions. The paper is structured with sections on main concepts, paradigms, and integration with LLMs.
#
# So, RAG stands for Retrieval-Augmented Generation. From the context, it's a method that combines retrieval of information with generation, likely in the context of large language models. The survey discusses different paradigms of RAG, such as naive RAG and more effective frameworks. The paper also emphasizes the integration of RAG within LLMs, which suggests that RAG enhances LLMs by retrieving relevant information before generating responses.
#
# The user might be looking for a concise definition, maybe with some examples of its applications or key components. Since the context doesn't mention specific applications, I should focus on the components and purpose. The answer should explain that RAG uses retrieval to gather information and then generates a response, improving the accuracy and relevance of the output. Also, the survey covers its evolution and evaluation methods, which shows that RAG is an active area of research with different approaches being developed.
#
# I need to make sure the answer is clear and not too technical, but still accurate. Avoid jargon where possible. Mention that RAG is used in LLMs to enhance their responses by retrieving relevant data. Also, note that the survey discusses different paradigms and evaluation methods, which indicates that RAG has multiple approaches and is being systematically studied.
# </think>
#
# **RAG (Retrieval-Augmented Generation)** is a method that enhances the capabilities of Large Language Models (LLMs) by integrating **information retrieval** with **text generation**. It works by first retrieving relevant documents or data from a knowledge source (e.g., databases, documents, or the web) and then using that retrieved information to generate more accurate, contextually relevant, and up-to-date responses. This approach addresses limitations of standalone LLMs, such as outdated knowledge or hallucinations, by grounding responses in external sources.
#
# ### Key Components of RAG:
# 1. **Retrieval**: A retriever (e.g., a dense or sparse vector search system) fetches relevant documents based on the input query.
# 2. **Generation**: A generator (often an LLM) synthesizes the retrieved information into a coherent answer, combining it with the model's internal knowledge.
#
# ### Evolution of RAG:
# - **Naive RAG**: Basic implementations where retrieval and generation are loosely coupled.
# - **Effective RAG Frameworks**: Advanced paradigms that optimize retrieval strategies, improve alignment between retrieved content and generation, and integrate fine-tuning techniques for better performance.
#
# ### Applications and Trends:
# - **Integration with LLMs**: RAG is increasingly used to augment LLMs in tasks like question-answering, summarization, and dialogue systems.
# - **Evaluation**: The field has developed benchmarks (e.g., 26 tasks, ~50 datasets) to assess RAG systems, focusing on metrics like retrieval accuracy, generation quality, and overall effectiveness.
# - **Future Directions**: Research is exploring improvements in retrieval efficiency, dynamic knowledge updates, and addressing challenges like scalability and handling noisy or conflicting retrieved data.
#
# In summary, RAG bridges the gap between static LLM knowledge and real-time information, enabling more reliable and context-aware AI systems.
